# %%
import pandas as pd
import numpy as np
import pymysql
from sqlalchemy import create_engine
import sqlite3
import getpass # To get the password without showing the input

# %%
pip install pymysql
# Out:
# ...
# Note: you may need to restart the kernel to use updated packages.

# %%
password = getpass.getpass()
# Out:
# ········

# %%
connection_string = 'mysql+pymysql://root:'+password+'@localhost/new_schema'
#root = name of the user
#database
#if working on a machine not local (localhost), could need to be changed to an ip address
engine = create_engine(connection_string)
# data = pd.read_sql_query('SELECT * FROM loan', engine)
# data.head()

#engine → creates a connection so you don't have to include password everytime

# %%
data = pd.read_csv('charts_top200_global.csv')
data.head()
# Out:
#    Unnamed: 0  Unnamed: 0.1  Unnamed: 0.1.1  \
# 0        3432          3432            3432
# 1        3433          3433            3433
# 2        3434          3434            3434
# 3        3435          3435            3435
# 4        3436          3436            3436
#
#                                 title  rank        date  \
# 0                        Shape of You     1  2017-04-01
# 1                        Passionfruit     2  2017-04-01
# 2     It Ain't Me (with Selena Gomez)     3  2017-04-01
# 3            Something Just Like This     4  2017-04-01
# 4  Despacito (Featuring Daddy Yankee)     5  2017-04-01
#
#                      artist_x  \
# 0                  Ed Sheeran
# 1                       Drake
# 2                        Kygo
# 3  The Chainsmokers, Coldplay
# 4                  Luis Fonsi
#
#                                                  url  region   chart  ...  \
# 0  https://open.spotify.com/track/7qiZfU4dY1lWllz...  Global  top200  ...
# ...

# %%
data = data.drop(['Unnamed: 0','Unnamed: 0.1','Unnamed: 0.1.1'],axis =1)

# %%
data.shape
# Out:
# (339982, 28)

# %%
data.to_sql('charts_top200_global', engine, if_exists='replace', index = False)

# %%
query = '''SELECT * FROM charts_top200_global;'''
check = pd.read_sql_query(query , engine)
check.head()
# Out:
#                                 title  rank        date  \
# 0                        Shape of You     1  2017-04-01
# 1                        Passionfruit     2  2017-04-01
# 2     It Ain't Me (with Selena Gomez)     3  2017-04-01
# 3            Something Just Like This     4  2017-04-01
# 4  Despacito (Featuring Daddy Yankee)     5  2017-04-01
#
#                      artist_x  \
# 0                  Ed Sheeran
# 1                       Drake
# 2                        Kygo
# 3  The Chainsmokers, Coldplay
# 4                  Luis Fonsi
#
#                                                  url  region   chart  \
# 0  https://open.spotify.com/track/7qiZfU4dY1lWllz...  Global  top200
# 1  https://open.spotify.com/track/7hDc8b7IXETo14h...  Global  top200
# 2  https://open.spotify.com/track/3eR23VReFzcdmS7...  Global  top200
# 3  https://open.spotify.com/track/6RUKPb4LETWmmr3...  Global  top200
# 4  https://open.spotify.com/track/4aWmUDTfIPGksMN...  Global  top200
#
# ...

# %%
query = '''SELECT title FROM charts_top200_global
where artist_x in ('Ed Sheeran');'''
check = pd.read_sql_query(query , engine)
check.head()
# Out:
#                 title
# 0        Shape of You
# 1         Galway Girl
# 2  Castle on the Hill
# 3             Perfect
# 4             Happier
